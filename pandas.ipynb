# %% [markdown]
# <a href="https://colab.research.google.com/github/banuben/ai_foundation/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
mydataset = {
'cars': ["BMW", "Volvo", "Ford"],
'counts': [3, 7, 2]
}
df = pd.DataFrame (mydataset)
print (df)
# Out:
#     cars  counts
# 0    BMW       3
# 1  Volvo       7
# 2   Ford       2

# %%
df.head()  #deafault 5rows

# %%
df.tail()

# %%
df.shape

# %%
df.columns

# %%
df.dtypes

# %%
df.describe(include='all') #numerical counts only

# %%
df.iloc[2] #call data by index

# %%
df.loc[2, "cars"]   #index, from(label) by column

# %%
df[df["counts"] > 3]

# %%
df.mean(numeric_only=True)

# %%
df["counts"].mean()

# %%
df.sum()

# %%
df.min()

# %%
df.max()

# %%
df.median(numeric_only=True)

# %%
df.count()

# %%
df.std(numeric_only=True)

# %%
data_with_missing = {
      "cars": ["BMW", "Volvo", None, "Tesla", "Ferrari", None, "Ford" ],
      "counts": [3, 7, None, 8, 1, 9, None]
}
df_missing = pd.DataFrame (data_with_missing)
print(df_missing)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     None     NaN
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5     None     9.0
# 6     Ford     NaN

# %%
df_missing.isnull().sum()
# Out:
# cars      2
# counts    2
# dtype: int64

# %%
df_missing.dropna(how="all")
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 3    Tesla     8.0
# 4  Ferrari     1.0

# %%
df_missing.dropna(subset="counts")

# %%
df.missing.fillna()

# %%
df = pd.read_csv("/Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.read_json("Titanic-Dataset.json")

df.head()

# %%
df = pd.read_excel("test.xlsx")

df.tail()

# %%
df.to_excel("test.xlsx")

# %%
cars = pd.Series(["BMW", "Tesla", "Ferrari"])

print(cars)

# %%
cars_series = data_with_missing ['cars']
print (cars_series)
