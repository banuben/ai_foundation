# %% [markdown]
# <a href="https://colab.research.google.com/github/banuben/ai_foundation/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import numpy as np
arr = np.array ( [1, 3, 5, 71])
print ( 'numpy_array:', arr)
arr. shape

# %%
arr2 = np.array ([[1, 3, 5, 71], [4, 6, 8, 91]])
print ( 'numpy_array2:', arr2)
arr2. shape

# %%
# dtype()
a = np.array ( [1, 2, 31)
print (a.dtype)

# %%
# reshape()
a = np.array ( [1, 2, 3, 4, 5, 61])
b = a. reshape (2, 3)
print ("shaped_array:", b)

# %%
# astype()
a = np.array ([1, 2,3])
b = a.astype(float)
print ("float:", b)

# %%
# np.zeros(), np.ones ()＝> dummy data
z = np.zeros ((2, 3))
o = np.ones ((2, 3))

print ("zeros:", z)
print("ones:", o)

# %%
# ndim
a = np.array ([1, 2], [3, 4])
print ("ndim:", a.ndim)

# %%
import numpy as np
# arange()
a = np.arange(1, 7)
print("arange:", a)
# Out:
# arange: [1 2 3 4 5 6]

# %%
# sum(), mean(), max(), min()
a = np.array ( [1, 2, 3, 4])

print("sum:", a.sum())
print("mean:", a.mean())
print("max:", a.max())
print("min:", a.min())
# Out:
# sum: 10
# mean: 2.5
# max: 4
# min: 1

# %%
# flatten()
a = np.array([[1, 21], [3, 4]])
print('flatten:', a.flatten())

# %%
# T (Transpose)
a = np.array([[1, 2], [3, 4]])
print("transpose:", a.T)
# Out:
# transpose: [[1 3]
#  [2 4]]

# %%
# dot() @
a = np.array([[1, 2], [3, 4]])
b = np.array([[2, 0],[1, 2]])
print ("dot/multiplication:", a.dot(b))
# Out:
# dot/multiplication: [[ 4  4]
#  [10  8]]

# %%
# random.rand()
a = np.random. rand (2, 3) # =＞ 0.0 and 1.0/ 0.0 included 1.0 excluded
print("random rand:", a)
